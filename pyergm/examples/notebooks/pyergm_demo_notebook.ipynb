# %% [markdown]
# ### Installing pyERGM

# %%
# -q to hide all installation logs but feel free to remove it.
# !pip3 install git+https://github.com/mallaham/pyERGM -q

# %%
# !pwd # can be used to know your local directory

# %%
import pyergm # to ensure all installation was successful

# %% [markdown]
# ### Importing pyERGM components

# %%
from pyergm import rpy_interface as rpyInterface
from pyergm.network_statistics import NetworkStats
from pyergm.ergm import pyERGM, ModelDiagnostics
from pyergm.simulator import Simulator
from pyergm.data_transformer import DataTransformer
import pandas as pd
from rpy2.robjects import NA_Real
# Out:
# NumExpr defaulting to 4 threads.

# %% [markdown]
# ### Setting up R environment

# %%
rpackages = ['statnet', 'ergm','texreg', 'base', 'grDevices']
renv = rpyInterface.intializeRenv(mirror=1, r_packages= rpackages)
installed_packages = renv.setup_renv()
# Out:
# Installing R packages...
# Importing package: statnet
# Importing package: ergm
# Importing package: texreg
# Importing package: base
# Importing package: grDevices

# %% [markdown]
# ### Loading and processing data

# %%
buyInFromYouEdgelist = pd.read_csv("buyInFromYouEdgelist.csv")

dt = DataTransformer(renv)
department = dt.rdf_to_list(dt.to_rdf(pd.read_csv("departmentNode.csv")), "department")
leader = dt.rdf_to_list(dt.to_rdf(pd.read_csv("leaderNode.csv")),"leader")
tenure = dt.rdf_to_list(dt.to_rdf(pd.read_csv("tenureNode.csv")), "tenure")
office = dt.rdf_to_list(dt.to_rdf(pd.read_csv("officeNode.csv")), "office")
female = dt.rdf_to_list(dt.to_rdf(pd.read_csv("femaleNode.csv")), "female")
messageEdgeList = pd.read_csv("messageEdgelist.csv")

# converting pandas dataframe to r
r_buyInFromYouEdgelist = dt.to_rdf(buyInFromYouEdgelist)

# loading edgelist as a matrix
buyIn = dt.edgelist_to_matrix(r_buyInFromYouEdgelist)

# set network attributes
buyIn = dt.set_vertex_attribute(buyIn, ["department","leader","tenure","office","female"], [department, leader, tenure, office, female])
# alternative method
# buyIn = dt.set_vertex_attribute(buyIn, "department", department) # Categorical variable for department
# buyIn = dt.set_vertex_attribute(buyIn, "leader", leader) # Indicator variable for department leader
# buyIn = dt.set_vertex_attribute(buyIn, "tenure",tenure) # Years tenure
# buyIn = dt.set_vertex_attribute(buyIn, "office", office) # Indicator variable for whether they are located in the main or secondary office
# buyIn = dt.set_vertex_attribute(buyIn, "female",female) # Indicator
# Out:
# Converting pandas DataFrame to R dataframe...
# Converting R dataframe to R list...
# Converting pandas DataFrame to R dataframe...
# Converting R dataframe to R list...
# Converting pandas DataFrame to R dataframe...
# Converting R dataframe to R list...
# Converting pandas DataFrame to R dataframe...
# Converting R dataframe to R list...
# Converting pandas DataFrame to R dataframe...
# Converting R dataframe to R list...
# Converting pandas DataFrame to R dataframe...
# Generating a matrix from edgelist...
# A list of attribute names and values was passed...
# Setting vertex attribute to department...
# Setting vertex attribute to leader...
# Setting vertex attribute to tenure...
# Setting vertex attribute to office...
# Setting vertex attribute to female...

# %% [markdown]
# ### Creating covariance matrix

# %%
cov_matrix = dt.cov_matrix(messageEdgeList, 'SenderId',' ReceiverId', 66, 66, NA_Real)

# filling matrix with values 
for index, row in messageEdgeList.iterrows():
    s_idx = int(row['SenderId'])
    r_idx = int(row['ReceiverId'])
    cov_matrix.rx[renv.load_robject('cbind')(s_idx,r_idx)] = float(row['MessagesSent']/100)
# Out:
# Generating covariance matrix for: None
# Importing package: base
# No covariance column was passed. Returning a matrix with populated values of NA_real_

# %% [markdown]
# ### Calculating network metrics

# %%
################################
## Calculate network metrics
################################
ns = NetworkStats(renv)
summary = ns.summary(buyIn)
print(summary)
network_size = ns.network_size(buyIn)
print(network_size)
betweeness = ns.betweeness(buyIn)
print(betweeness)
isolates = ns.isolates(buyIn)
print(isolates)
# Out:
# Calculating network summary statistics...
# Network attributes:
#   vertices = 66
#   directed = TRUE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#  total edges = 225
#    missing edges = 0
#    non-missing edges = 225
#  density = 0.05244755
#
# Vertex attributes:
#
#  department:
#    character valued attribute
#    attribute summary:
#    BE    ME     O     P     S Sales    TI    WB    WF
#    10    18     2    13     5     1     9     1     7
#
#  female:
#    integer valued attribute
#    66 values
#
#  leader:
#    integer valued attribute
#    66 values
#
#  office:
#    integer valued attribute
#    66 values
#
#  tenure:
#    integer valued attribute
#    66 values
#   vertex.names:
#    character valued attribute
#    66 valid vertex names
#
# No edge attributes
#
# Network edgelist matrix:
#        [,1] [,2]
#   [1,]    1   31
#   [2,]    1   57
#   [3,]    2   31
#   [4,]    2   59
#   [5,]    3   24
#   [6,]    3   33
#   [7,]    3   52
#   [8,]    4   14
#   [9,]    4   17
#  [10,]    4   23
#  [11,]    4   63
#  [12,]    4   65
#  [13,]    5   31
#  [14,]    5   57
#  [15,]    5   59
#  [16,]    6   14
#  [17,]    6   23
#  [18,]    6   28
#  [19,]    6   35
#  [20,]    6   36
#  [21,]    7   14
#  [22,]    7   23
#  [23,]    7   35
#  [24,]    7   36
#  [25,]    7   63
#  [26,]    8   15
#  [27,]    8   40
#  [28,]    8   53
#  [29,]    9    2
#  [30,]    9   13
#  [31,]    9   29
#  [32,]    9   31
#  [33,]    9   59
#  [34,]   10   23
#  [35,]   10   28
#  [36,]   10   35
#  [37,]   10   52
#  [38,]   11   15
#  [39,]   11   52
#  [40,]   12   52
#  [41,]   13   14
#  [42,]   13   15
#  [43,]   13   23
#  [44,]   13   31
#  [45,]   13   57
#  [46,]   14   15
#  [47,]   14   23
#  [48,]   14   35
#  [49,]   14   40
#  [50,]   14   52
#  [51,]   15   35
#  [52,]   15   40
#  [53,]   15   54
#  [54,]   15   63
#  [55,]   15   65
#  [56,]   16   23
#  [57,]   16   35
#  [58,]   17   14
#  [59,]   17   15
#  [60,]   17   23
#  [61,]   17   33
#  [62,]   17   65
#  [63,]   18   31
#  [64,]   19   15
#  [65,]   19   23
#  [66,]   19   52
#  [67,]   19   63
#  [68,]   20   13
#  [69,]   20   14
#  [70,]   20   15
#  [71,]   20   52
#  [72,]   20   65
#  [73,]   21   14
#  [74,]   21   15
#  [75,]   21   23
#  [76,]   21   31
#  [77,]   21   35
#  [78,]   22   14
#  [79,]   22   15
#  [80,]   23   14
#  [81,]   23   15
#  [82,]   23   31
#  [83,]   23   35
#  [84,]   23   37
#  [85,]   24   15
#  [86,]   24   40
#  [87,]   25   15
#  [88,]   25   23
#  [89,]   25   31
#  [90,]   25   35
#  [91,]   26   15
#  [92,]   26   23
#  [93,]   26   40
#  [94,]   26   52
#  [95,]   28   52
#  [96,]   30   13
#  [97,]   30   20
#  [98,]   30   29
#  [99,]   30   39
# [100,]   30   59
# [101,]   31   13
# [102,]   31   14
# [103,]   31   15
# [104,]   31   23
# [105,]   31   57
# [106,]   32   14
# [107,]   32   23
# [108,]   32   31
# [109,]   32   35
# [110,]   32   63
# [111,]   33   14
# [112,]   33   15
# [113,]   33   23
# [114,]   34   23
# [115,]   34   63
# [116,]   35   15
# [117,]   35   23
# [118,]   36   14
# [119,]   36   15
# [120,]   36   23
# [121,]   36   25
# [122,]   36   35
# [123,]   37   23
# [124,]   37   25
# [125,]   37   34
# [126,]   37   63
# [127,]   38   15
# [128,]   38   40
# [129,]   39   13
# [130,]   39   15
# [131,]   39   23
# [132,]   39   31
# [133,]   39   57
# [134,]   40   15
# [135,]   40   52
# [136,]   41   52
# [137,]   42   14
# [138,]   42   15
# [139,]   42   26
# [140,]   42   40
# [141,]   42   52
# [142,]   43    4
# [143,]   43   14
# [144,]   43   29
# [145,]   43   31
# [146,]   43   57
# [147,]   44   14
# [148,]   44   15
# [149,]   44   65
# [150,]   45   15
# [151,]   45   23
# [152,]   45   31
# [153,]   45   57
# [154,]   46   14
# [155,]   46   15
# [156,]   46   23
# [157,]   46   31
# [158,]   46   57
# [159,]   47   52
# [160,]   48   14
# [161,]   48   23
# [162,]   48   63
# [163,]   49   15
# [164,]   49   23
# [165,]   50   15
# [166,]   50   24
# [167,]   50   40
# [168,]   50   52
# [169,]   51   24
# [170,]   51   38
# [171,]   51   40
# [172,]   51   50
# [173,]   51   64
# [174,]   52   15
# [175,]   53    8
# [176,]   53   15
# [177,]   53   40
# [178,]   54   14
# [179,]   54   15
# [180,]   54   23
# [181,]   55   14
# [182,]   55   15
# [183,]   55   25
# [184,]   55   35
# [185,]   55   36
# [186,]   56   14
# [187,]   56   15
# [188,]   56   23
# [189,]   56   63
# [190,]   56   65
# [191,]   57   15
# [192,]   58    5
# [193,]   58   31
# [194,]   58   45
# [195,]   58   57
# [196,]   59   14
# [197,]   59   31
# [198,]   59   63
# [199,]   60   14
# [200,]   60   52
# [201,]   60   63
# [202,]   61   15
# [203,]   61   23
# [204,]   61   48
# [205,]   61   60
# [206,]   61   63
# [207,]   62   14
# [208,]   62   15
# [209,]   63   14
# [210,]   63   15
# [211,]   63   23
# [212,]   63   26
# [213,]   63   52
# [214,]   64   15
# [215,]   64   24
# [216,]   64   38
# [217,]   64   40
# [218,]   64   51
# [219,]   65   14
# [220,]   65   15
# [221,]   65   23
# [222,]   65   35
# [223,]   66   25
# [224,]   66   35
# [225,]   66   36
#
# Calculating network size...
# [1] 66
#
# Calculating network betweenness...
#  [1]   0.000000   0.000000   0.000000   6.333333   1.500000   0.000000
#  [7]   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# [13]  13.778571  95.878571 381.585714   0.000000   2.400000   0.000000
# [19]   0.000000   3.666667   0.000000   0.000000 337.741270   5.666667
# [25]  14.333333   4.200000   0.000000   0.500000   0.000000   0.000000
# [31] 167.478571   0.000000  10.266667   0.000000  38.016667   9.666667
# [37] 121.566667   2.800000   3.888889  10.666667   0.000000   0.000000
# [43]   0.000000   0.000000   4.083333   0.000000   0.000000   0.250000
# [49]   0.000000   3.300000   1.000000  64.616667   0.000000  33.083333
# [55]   0.000000   0.000000   7.616667   0.000000  13.987302   0.750000
# [61]   0.000000   0.000000 117.650000   2.800000  39.927778   0.000000
#
# Calculating number of isolates in the network...
# [1] 27

# %% [markdown]
# ### ERGM model

# %%
# ERGM model
# formula and input variables
formula = "buyIn ~ edges + mutual + edgecov(hundreds_messages) + nodemix('leader',base = 3)"
vars = {"buyIn": buyIn, "hundred_messages": cov_matrix, "hundreds_messages": cov_matrix}

# model definition and parameters
ergm = pyERGM(installed_packages['ergm'], formula, vars, constraints="~bd(maxout=5)")
params = dict({"formula":ergm.formula, "constraints":ergm.constraints}) # make sure to include = for parameters that require = vs parameters that can be upacked such as formula
model = ergm.fit_model(params)
summary = ergm.summary(model)
print(summary)
# Out:
# Model summary before fitting ERGM...
# In term ‘nodemix’ in package ‘ergm’: Argument ‘base’ has been superseded by ‘levels2’, and it is recommended to use the latter.  Note that its interpretation may be different.
#                            c(edges = 225, mutual = 12, edgecov.hundreds_messages = 56.69, mix.leader.0.0 = 94, mix.leader.1.0 = 8, mix.leader.1.1 = 12)
# edges                                                                 225.00
# mutual                                                                 12.00
# edgecov.hundreds_messages                                              56.69
# mix.leader.0.0                                                         94.00
# mix.leader.1.0                                                          8.00
# mix.leader.1.1                                                         12.00
# Fitting ERGM model...
# R[write to console]: Starting contrastive divergence estimation via CD-MCMLE:
#
# R[write to console]: Iteration 1 of at most 60:
#
# R[write to console]: Convergence test P-value:4.5e-320
#
# R[write to console]: Warning:
# R[write to console]:  ‘glpk’ selected as the solver, but package ‘Rglpk’ is not available; falling back to ‘lpSolveAPI’. This should be fine unless the sample size and/or the number of parameters is very big.
#
# R[write to console]: The log-likelihood improved by 1.603.
#
# R[write to console]: Iteration 2 of at most 60:
#
# R[write to console]: Convergence test P-value:1.2e-245
#
# R[write to console]: The log-likelihood improved by 1.348.
#
# R[write to console]: Iteration 3 of at most 60:
#
# R[write to console]: Convergence test P-value:9.5e-101
#
# R[write to console]: The log-likelihood improved by 0.4182.
#
# R[write to console]: Iteration 4 of at most 60:
#
# R[write to console]: Convergence test P-value:2.7e-28
#
# R[write to console]: The log-likelihood improved by 0.1019.
#
# R[write to console]: Iteration 5 of at most 60:
#
# R[write to console]: Convergence test P-value:3.8e-05
#
# R[write to console]: The log-likelihood improved by 0.01976.
#
# R[write to console]: Iteration 6 of at most 60:
#
# R[write to console]: Convergence test P-value:1.4e-04
#
# R[write to console]: The log-likelihood improved by 0.01836.
#
# R[write to console]: Iteration 7 of at most 60:
#
# R[write to console]: Convergence test P-value:2.8e-01
#
# R[write to console]: The log-likelihood improved by 0.004984.
#
# R[write to console]: Iteration 8 of at most 60:
#
# R[write to console]: Convergence test P-value:2e-02
#
# R[write to console]: The log-likelihood improved by 0.009351.
#
# R[write to console]: Iteration 9 of at most 60:
#
# R[write to console]: Convergence test P-value:7.3e-02
#
# R[write to console]: The log-likelihood improved by 0.00769.
#
# R[write to console]: Iteration 10 of at most 60:
#
# R[write to console]: Convergence test P-value:3.7e-02
#
# R[write to console]: The log-likelihood improved by 0.008862.
#
# R[write to console]: Iteration 11 of at most 60:
#
# R[write to console]: Convergence test P-value:8.5e-01
#
# R[write to console]: Convergence detected. Stopping.
#
# R[write to console]: The log-likelihood improved by 0.001713.
#
# R[write to console]: Finished CD.
#
# R[write to console]: Starting Monte Carlo maximum likelihood estimation (MCMLE):
#
# R[write to console]: Iteration 1 of at most 60:
#
# R[write to console]: Optimizing with step length 0.2365.
#
# R[write to console]: The log-likelihood improved by 1.5956.
#
# R[write to console]: Estimating equations are not within tolerance region.
#
# R[write to console]: Iteration 2 of at most 60:
#
# R[write to console]: Optimizing with step length 0.4849.
#
# R[write to console]: The log-likelihood improved by 2.5689.
#
# R[write to console]: Estimating equations are not within tolerance region.
#
# R[write to console]: Iteration 3 of at most 60:
#
# R[write to console]: Optimizing with step length 0.6893.
#
# R[write to console]: The log-likelihood improved by 1.9969.
#
# R[write to console]: Estimating equations are not within tolerance region.
#
# R[write to console]: Iteration 4 of at most 60:
#
# R[write to console]: Optimizing with step length 1.0000.
#
# R[write to console]: The log-likelihood improved by 0.3152.
#
# R[write to console]: Estimating equations are not within tolerance region.
#
# R[write to console]: Iteration 5 of at most 60:
#
# R[write to console]: Optimizing with step length 1.0000.
#
# R[write to console]: The log-likelihood improved by 0.7041.
#
# R[write to console]: Estimating equations are not within tolerance region.
#
# R[write to console]: Iteration 6 of at most 60:
#
# R[write to console]: Optimizing with step length 1.0000.
#
# R[write to console]: The log-likelihood improved by 0.7884.
#
# R[write to console]: Estimating equations are not within tolerance region.
#
# R[write to console]: Estimating equations did not move closer to tolerance region more than 1 time(s) in 4 steps; increasing sample size.
#
# R[write to console]: Iteration 7 of at most 60:
#
# R[write to console]: Optimizing with step length 1.0000.
#
# R[write to console]: The log-likelihood improved by 0.0366.
#
# R[write to console]: Convergence test p-value: 0.3198.
# R[write to console]: Not converged with 99% confidence; increasing sample size.
#
# R[write to console]: Iteration 8 of at most 60:
#
# R[write to console]: Optimizing with step length 1.0000.
#
# R[write to console]: The log-likelihood improved by 0.0442.
#
# R[write to console]: Convergence test p-value: 0.1529.
# R[write to console]: Not converged with 99% confidence; increasing sample size.
#
# R[write to console]: Iteration 9 of at most 60:
#
# R[write to console]: Optimizing with step length 1.0000.
#
# R[write to console]: The log-likelihood improved by 0.0220.
#
# R[write to console]: Convergence test p-value: 0.0001.
# R[write to console]: Converged with 99% confidence.
#
# R[write to console]: Finished MCMLE.
#
# R[write to console]: Evaluating log-likelihood at the estimate.
# R[write to console]: Setting up bridge sampling...
#
# R[write to console]: Using 16 bridges:
# R[write to console]: 1
# R[write to console]: 2
# R[write to console]: 3
# R[write to console]: 4
# R[write to console]: 5
# R[write to console]: 6
# R[write to console]: 7
# R[write to console]: 8
# R[write to console]: 9
# R[write to console]: 10
# R[write to console]: 11
# R[write to console]: 12
# R[write to console]: 13
# R[write to console]: 14
# R[write to console]: 15
# R[write to console]: 16
# R[write to console]: .
#
# R[write to console]: Note: The constraint on the sample space is not dyad-independent. Null
# model likelihood is only implemented for dyad-independent constraints
# at this time. Number of observations is similarly poorly defined.  This
# means that all likelihood-based inference (LRT, Analysis of Deviance,
# AIC, BIC, etc.) is only valid between models with the same reference
# distribution and constraints.
#
# R[write to console]: This model was fit using MCMC.  To examine model diagnostics and check
# for degeneracy, use the mcmc.diagnostics() function.
#
# Function executed in 11.2434 seconds
# ERGM model summary...
# Importing package: texreg
# Function executed in 0.3397 seconds
#
# ======================================
#                            Model 1
# --------------------------------------
# edges                        -0.67 ***
#                              (0.13)
# mutual                        1.12 **
#                              (0.43)
# edgecov.hundreds_messages     0.34 ***
#                              (0.10)
# mix.leader.0.0               -2.79 ***
#                              (0.16)
# mix.leader.1.0               -3.46 ***
#                              (0.51)
# mix.leader.1.1               -0.11
#                              (0.43)
# --------------------------------------
# AIC                        -715.32
# BIC                        -677.13
# Log Likelihood              363.66
# ======================================
# *** p < 0.001; ** p < 0.01; * p < 0.05
#  FALSE

# %% [markdown]
# ### Model diagnostics

# %%
#####################
## Model Diagnositics
#####################
ergm_diagnostics = ModelDiagnostics(renv)

# MCMC
filename, mcmc_results = ergm_diagnostics.run_mcmc(model)
print(filename)
# Out:
# Running MCMC diagnostics with seed 321...
# Sample statistics summary:
#
# Iterations = 118784:2353152
# Thinning interval = 2048
# Number of chains = 1
# Sample size per chain = 1092
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                               Mean     SD Naive SE Time-series SE
# edges                      0.07692 10.425  0.31547         0.3925
# mutual                    -0.14377  2.953  0.08937         0.1107
# edgecov.hundreds_messages -0.72039 10.754  0.32543         0.5053
# mix.leader.0.0            -0.71520  8.036  0.24319         0.2815
# mix.leader.1.0             0.25733  2.461  0.07447         0.0787
# mix.leader.1.1            -0.38370  2.839  0.08592         0.1641
#
# 2. Quantiles for each variable:
#
#                             2.5%    25%   50%   75% 97.5%
# edges                     -19.00 -7.000  0.00 7.000 20.00
# mutual                     -5.00 -2.000  0.00 2.000  6.00
# edgecov.hundreds_messages -20.65 -8.318 -0.78 6.262 20.43
# mix.leader.0.0            -15.00 -6.000 -1.00 5.000 16.00
# mix.leader.1.0             -4.00 -1.000  0.00 2.000  5.00
# mix.leader.1.1             -6.00 -2.000  0.00 2.000  5.00
#
#
# Are sample statistics significantly different from observed?
#                 edges     mutual edgecov.hundreds_messages mix.leader.0.0
# diff.      0.07692308 -0.1437729                -0.7203938     -0.7152015
# test stat. 0.19597894 -1.2993234                -1.4255437     -2.5404498
# P-val.     0.84462665  0.1938330                 0.1540001      0.0110710
#            mix.leader.1.0 mix.leader.1.1 Overall (Chi^2)
# diff.         0.257326007    -0.38369963              NA
# test stat.    3.269669534    -2.33791558    22.102689928
# P-val.        0.001076732     0.01939163     0.001413725
#
# Sample statistics cross-correlations:
#                               edges    mutual edgecov.hundreds_messages
# edges                     1.0000000 0.3566557                0.16470507
# mutual                    0.3566557 1.0000000                0.19880665
# edgecov.hundreds_messages 0.1647051 0.1988066                1.00000000
# mix.leader.0.0            0.5349532 0.2022172                0.17705917
# mix.leader.1.0            0.2182843 0.3937006                0.04552444
# mix.leader.1.1            0.1920110 0.2729521                0.02556564
#                           mix.leader.0.0 mix.leader.1.0 mix.leader.1.1
# edges                         0.53495316     0.21828433     0.19201097
# mutual                        0.20221718     0.39370063     0.27295208
# edgecov.hundreds_messages     0.17705917     0.04552444     0.02556564
# mix.leader.0.0                1.00000000     0.01946532    -0.04490017
# mix.leader.1.0                0.01946532     1.00000000    -0.26923072
# mix.leader.1.1               -0.04490017    -0.26923072     1.00000000
#
# Sample statistics auto-correlation:
# Chain 1
#                  edges     mutual edgecov.hundreds_messages mix.leader.0.0
# Lag 0      1.000000000 1.00000000                1.00000000     1.00000000
# Lag 2048   0.161823980 0.06974153                0.39348082     0.08870153
# Lag 4096   0.079023994 0.04400343                0.21913569     0.06389763
# Lag 6144   0.038759324 0.01607394                0.06474020     0.03950513
# Lag 8192  -0.012888667 0.09480943                0.03109795    -0.02292982
# Lag 10240 -0.005442133 0.01399774                0.01472850    -0.03439280
#           mix.leader.1.0 mix.leader.1.1
# Lag 0        1.000000000      1.0000000
# Lag 2048     0.054775148      0.5694909
# Lag 4096     0.036684057      0.3511928
# Lag 6144     0.045223752      0.2280007
# Lag 8192     0.021069321      0.1511154
# Lag 10240   -0.001952114      0.1241319
#
# Sample statistics burn-in diagnostic (Geweke):
# Chain 1
#
# Fraction in 1st window = 0.1
# Fraction in 2nd window = 0.5
#
#                     edges                    mutual edgecov.hundreds_messages
#                    1.9986                    2.4881                   -0.2994
#            mix.leader.0.0            mix.leader.1.0            mix.leader.1.1
#                   -1.6850                    1.2304                    0.3364
#
# Individual P-values (lower = worse):
#                     edges                    mutual edgecov.hundreds_messages
#                0.04565023                0.01284426                0.76465533
#            mix.leader.0.0            mix.leader.1.0            mix.leader.1.1
#                0.09199034                0.21854178                0.73654617
# Joint P-value (lower = worse):  0.03135708 .
#
# MCMC diagnostics shown here are from the last round of simulation, prior to computation of final parameter estimates. Because the final estimates are refinements of those used for this simulation run, these diagnostics may understate model performance. To directly assess the performance of the final model on in-model statistics, please use the GOF command: gof(ergmFitObject, GOF=~model).
# MCMC diagnostic report can be accessed in the following path: ./mcmc_diagnostics.pdf
# Function executed in 1.9132 seconds
# ./mcmc_diagnostics.pdf

# %% [markdown]
# ### Goodness of fit test

# %%
## Goodness of fit
gof_params = dict({"verbose=":"T","burnin=":1e+5,"interval=":1e+5})
gof = ergm_diagnostics.gof(model, gof_params, n=100)
print(gof)
# Out:
# Running goodness of fit test...
# Importing package: grDevices
# Goodness of fit report can be accessed in the following path: ./gof_report.png
# Function executed in 7.1200 seconds
#
# Goodness-of-fit for in-degree
#
#           obs min  mean max MC p-value
# idegree0   29   4 11.36  18       0.00
# idegree1   17  12 18.44  28       0.94
# idegree2    4   8 15.74  26       0.00
# idegree3    1   4  9.19  15       0.00
# idegree4    4   0  3.60   8       0.96
# idegree5    1   0  1.18   5       1.00
# idegree6    1   0  0.39   3       0.66
# idegree7    0   0  0.07   1       1.00
# idegree8    0   0  0.03   1       1.00
# idegree9    1   0  0.00   0       0.00
# idegree10   0   0  0.01   1       1.00
# idegree11   1   0  0.07   1       0.14
# idegree12   1   0  0.08   1       0.16
# idegree13   0   0  0.09   1       1.00
# idegree14   1   0  0.17   2       0.30
# idegree15   0   0  0.22   2       1.00
# idegree16   2   0  0.35   3       0.14
# idegree17   0   0  0.42   2       1.00
# idegree18   0   0  0.41   3       1.00
# idegree19   0   0  0.61   3       1.00
# idegree20   0   0  0.56   3       1.00
# idegree21   0   0  0.66   2       0.96
# idegree22   0   0  0.51   2       1.00
# idegree23   0   0  0.49   2       1.00
# idegree24   0   0  0.40   3       1.00
# idegree25   0   0  0.29   1       1.00
# idegree26   1   0  0.32   2       0.56
# idegree27   0   0  0.13   1       1.00
# idegree28   0   0  0.06   1       1.00
# idegree29   1   0  0.09   1       0.18
# idegree30   0   0  0.04   1       1.00
# idegree31   0   0  0.02   1       1.00
# idegree37   1   0  0.00   0       0.00
#
# Goodness-of-fit for out-degree
#
#          obs min  mean max MC p-value
# odegree0   2   0  0.79   5       0.38
# odegree1   7   0  4.41  12       0.26
# odegree2  12   3 10.80  22       0.78
# odegree3  11   9 16.79  29       0.20
# odegree4   9  10 18.84  29       0.00
# odegree5  25   6 14.37  23       0.00
#
# Goodness-of-fit for edgewise shared partner
#
#      obs min   mean max MC p-value
# esp0  69 105 133.02 160       0.00
# esp1  69  41  57.50  76       0.16
# esp2  39  10  25.94  45       0.12
# esp3  27   0   6.47  18       0.00
# esp4  21   0   0.66   6       0.00
#
# Goodness-of-fit for minimum geodesic distance
#
#      obs min    mean  max MC p-value
# 1    225 198  223.59  249       0.86
# 2    376 347  480.51  635       0.04
# 3    285 282  610.38  996       0.02
# 4     93 230  608.73  994       0.00
# 5     49 197  481.18  817       0.00
# 6     20  94  310.38  522       0.00
# 7      0   7  175.03  376       0.00
# 8      0   0   91.98  265       0.02
# 9      0   0   47.77  210       0.32
# 10     0   0   24.84  191       0.68
# 11     0   0   12.35  140       1.00
# 12     0   0    6.70  133       1.00
# 13     0   0    4.47  166       1.00
# 14     0   0    2.92  156       1.00
# 15     0   0    1.85  109       1.00
# 16     0   0    0.77   54       1.00
# 17     0   0    0.18   17       1.00
# 18     0   0    0.01    1       1.00
# Inf 3242 450 1206.36 2677       0.00
#
# Goodness-of-fit for model statistics
#
#                              obs    min     mean    max MC p-value
# edges                     225.00 198.00 223.5900 249.00       0.86
# mutual                     12.00   5.00  12.0700  21.00       1.00
# edgecov.hundreds_messages  56.69  23.93  55.7615  85.57       0.94
# mix.leader.0.0             94.00  75.00  93.2800 116.00       1.00
# mix.leader.1.0              8.00   3.00   7.5800  15.00       1.00
# mix.leader.1.1             12.00   7.00  12.6800  21.00       1.00

# %% [markdown]
# ### Simulating networks

# %%
###############
## Simulations
###############
sim_parms = {"burnin=":100000, "interval=":100000, "verbose=":"T", "seed=":10}
simulator = Simulator(model, sim_parms)
sim_results = simulator.simulate()
print(len(simulator.get_triangles()))
# Out:
# Simulating 1000 networks with seed vale 340...
# Counting the number of triangles in the simulated networks...
# 1000
